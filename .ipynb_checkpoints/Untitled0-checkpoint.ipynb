# %%
import twitter
import json
from collections import Counter
from prettytable import PrettyTable
import matplotlib.pyplot as plt

CONSUMER_KEY = '9WQ8uPw0E6XjnN5Fpe4wQ'
CONSUMER_SECRET = 'eqRTSHzkDUe78lKLShsX7YvaecUaonr5xkglyFxEhEc'
OAUTH_TOKEN = '931200800-vVarLuafor9AAyrQ7Q3RHS0QOJux5WUw67QLLgyk'
OAUTH_TOKEN_SECRET = 'KSKyxgV6ucWqUvwmuVDYfJbZlenA83AYnVWlx1kBxONSn'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)
twitter_api = twitter.Twitter(auth=auth)

#Collect search results
# XXX: Set this variable to a trending topic, or anything else for that matter.
q = '#manunited'
user_id = '155659213'
screen_name = 'Cristiano'
count = 100
index = 0
search_results = twitter_api.statuses.user_timeline(user_id = user_id, screen_name = screen_name, count = count)
#search_results = twitter_api.search.tweets(q = q, count = count)
#statuses = search_results['statuses']
for tweet in search_results:
	while index < 100:
		retweet_count = search_results[index]['retweet_count']
		if(retweet_count > 10000):
			retweet_id = search_results[index]['id']
			print retweet_id
			get_retweet = twitter_api.statuses.retweets.id(id = retweet_id, count = 10)
			index_retweet = 0
			while index_retweet < 10:
				print get_retweet[index_retweet]['user']['screen_name']
				index_retweet += 1
		index += 1
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-c6bfe036edd7> in <module>()
# ----> 1 import twitter
#       2 import json
#       3 from collections import Counter
#       4 from prettytable import PrettyTable
#       5 import matplotlib.pyplot as plt
#
# ImportError: No module named twitter

# %%
import twitter

# %%
import twitter
import json
from collections import Counter
import matplotlib.pyplot as plt

CONSUMER_KEY = '9WQ8uPw0E6XjnN5Fpe4wQ'
CONSUMER_SECRET = 'eqRTSHzkDUe78lKLShsX7YvaecUaonr5xkglyFxEhEc'
OAUTH_TOKEN = '931200800-vVarLuafor9AAyrQ7Q3RHS0QOJux5WUw67QLLgyk'
OAUTH_TOKEN_SECRET = 'KSKyxgV6ucWqUvwmuVDYfJbZlenA83AYnVWlx1kBxONSn'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)
twitter_api = twitter.Twitter(auth=auth)

#Collect search results
# XXX: Set this variable to a trending topic, or anything else for that matter.
q = '#manunited'
user_id = '155659213'
screen_name = 'Cristiano'
count = 100
index = 0
search_results = twitter_api.statuses.user_timeline(user_id = user_id, screen_name = screen_name, count = count)
#search_results = twitter_api.search.tweets(q = q, count = count)
#statuses = search_results['statuses']
for tweet in search_results:
	while index < 100:
		retweet_count = search_results[index]['retweet_count']
		if(retweet_count > 10000):
			retweet_id = search_results[index]['id']
			print retweet_id
			get_retweet = twitter_api.statuses.retweets.id(id = retweet_id, count = 10)
			index_retweet = 0
			while index_retweet < 10:
				print get_retweet[index_retweet]['user']['screen_name']
				index_retweet += 1
		index += 1
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-c6bfe036edd7> in <module>()
#       2 import json
#       3 from collections import Counter
# ----> 4 from prettytable import PrettyTable
#       5 import matplotlib.pyplot as plt
#       6
#
# ImportError: No module named prettytable

# %%
import twitter
import json
from collections import Counter

import matplotlib.pyplot as plt

CONSUMER_KEY = '9WQ8uPw0E6XjnN5Fpe4wQ'
CONSUMER_SECRET = 'eqRTSHzkDUe78lKLShsX7YvaecUaonr5xkglyFxEhEc'
OAUTH_TOKEN = '931200800-vVarLuafor9AAyrQ7Q3RHS0QOJux5WUw67QLLgyk'
OAUTH_TOKEN_SECRET = 'KSKyxgV6ucWqUvwmuVDYfJbZlenA83AYnVWlx1kBxONSn'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)
twitter_api = twitter.Twitter(auth=auth)

#Collect search results
# XXX: Set this variable to a trending topic, or anything else for that matter.
q = '#manunited'
user_id = '155659213'
screen_name = 'Cristiano'
count = 100
index = 0
search_results = twitter_api.statuses.user_timeline(user_id = user_id, screen_name = screen_name, count = count)
#search_results = twitter_api.search.tweets(q = q, count = count)
#statuses = search_results['statuses']
for tweet in search_results:
	while index < 100:
		retweet_count = search_results[index]['retweet_count']
		if(retweet_count > 10000):
			retweet_id = search_results[index]['id']
			print retweet_id
			get_retweet = twitter_api.statuses.retweets.id(id = retweet_id, count = 10)
			index_retweet = 0
			while index_retweet < 10:
				print get_retweet[index_retweet]['user']['screen_name']
				index_retweet += 1
		index += 1
# Out:
# 408728693834776576
# hidiriqhwan
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-4765b44f43fd> in <module>()
#      33                         index_retweet = 0
#      34                         while index_retweet < 10:
# ---> 35                                 print get_retweet[index_retweet]['user']['screen_name']
#      36                                 index_retweet += 1
#      37                 index += 1
#
# IndexError: list index out of range
# SAYP11
# DiogoVieira007
# khalid_143143
# iremseven28
# BBKPlange
# JoshFrd
# Pacomoya7
# Faalii_Niium

# %%
q = '#manunited'
user_id = '155659213'
screen_name = 'Cristiano'
count = 100
index = 0
search_results = twitter_api.statuses.user_timeline(user_id = user_id, screen_name = screen_name, count = count)
#search_results = twitter_api.search.tweets(q = q, count = count)
search_results
# Out:
# [{u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Fri Dec 13 18:07:45 +0000 2013',
#   u'entities': {u'hashtags': [{u'indices': [39, 48], u'text': u'GALAXY11'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'youtu.be/86wGkXjgEjI',
#      u'expanded_url': u'http://youtu.be/86wGkXjgEjI',
#      u'indices': [115, 137],
#      u'url': u'http://t.co/TCTSzsPOcn'}],
#    u'user_mentions': []},
#   u'favorite_count': 292,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 411558072017231872,
#   u'id_str': u'411558072017231872',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 437,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   u'text': u"The Alien threat is here - I've joined #GALAXY11 to play football in space and defend this planet that we love...\xa0\nhttp://t.co/TCTSzsPOcn",
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Fri Dec 13 16:59:53 +0000 2013',
#   u'entities': {u'hashtags': [{u'indices': [66, 78], u'text': u'VivaRonaldo'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 472428172,
#      u'id_str': u'472428172',
#      u'indices': [86, 98],
#      u'name': u'Viva Ronaldo',
#      u'screen_name': u'VivaRonaldo'}]},
#   u'favorite_count': 657,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 411540994057076737,
#   u'id_str': u'411540994057076737',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'pt',
#   u'place': None,
#   u'retweet_count': 856,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.vivaronaldo.com" rel="nofollow">Viva Ronaldo</a>',
#   u'text': u'Acabei de fazer as minhas previs\xf5es para o Osasuna vs. Team CR no #VivaRonaldo. E tu? @VivaRonaldo',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Dec 12 18:38:04 +0000 2013',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 222600571,
#      u'id_str': u'222600571',
#      u'indices': [0, 15],
#      u'name': u'Fundaci\xf3n Revel',
#      u'screen_name': u'FundacionRevel'}]},
#   u'favorite_count': 322,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 411203315850964992,
#   u'id_str': u'411203315850964992',
#   u'in_reply_to_screen_name': u'FundacionRevel',
#   u'in_reply_to_status_id': 411194313540788224,
#   u'in_reply_to_status_id_str': u'411194313540788224',
#   u'in_reply_to_user_id': 222600571,
#   u'in_reply_to_user_id_str': u'222600571',
#   u'lang': u'es',
#   u'place': None,
#   u'retweet_count': 312,
#   u'retweeted': False,
#   u'source': u'web',
#   u'text': u'@FundacionRevel Gracias a todos. Feliz Navidad!',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Dec 12 17:05:39 +0000 2013',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/ujNnQm4lO0',
#      u'expanded_url': u'http://twitter.com/Cristiano/status/411180054534582272/photo/1',
#      u'id': 411180054542970880,
#      u'id_str': u'411180054542970880',
#      u'indices': [95, 117],
#      u'media_url': u'http://pbs.twimg.com/media/BbTOFMHCcAAhoXn.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/BbTOFMHCcAAhoXn.jpg',
#      u'sizes': {u'large': {u'h': 1032, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 604, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 343, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/ujNnQm4lO0'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'vivaronaldo.com',
#      u'expanded_url': u'http://vivaronaldo.com',
#      u'indices': [72, 94],
#      u'url': u'http://t.co/GWxiDwVO06'}],
#    u'user_mentions': [{u'id': 472428172,
#      u'id_str': u'472428172',
#      u'indices': [1, 13],
#      u'name': u'Viva Ronaldo',
#      u'screen_name': u'VivaRonaldo'}]},
#   u'favorite_count': 1736,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 411180054534582272,
#   u'id_str': u'411180054534582272',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 2013,
#   u'retweeted': False,
#   u'source': u'web',
#   u'text': u'.@VivaRonaldo is where my true fans belong. Join my official community. http://t.co/GWxiDwVO06 http://t.co/ujNnQm4lO0',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Wed Dec 11 18:22:28 +0000 2013',
#   u'entities': {u'hashtags': [{u'indices': [73, 86],
#      u'text': u'CR7underwear'}],
#    u'media': [{u'display_url': u'pic.twitter.com/OJqfBhEXm5',
#      u'expanded_url': u'http://twitter.com/Cristiano/status/410836999906410496/photo/1',
#      u'id': 410836999910604800,
#      u'id_str': u'410836999910604800',
#      u'indices': [116, 138],
#      u'media_url': u'http://pbs.twimg.com/media/BbOWEyBCQAAhjJE.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/BbOWEyBCQAAhjJE.jpg',
#      u'sizes': {u'large': {u'h': 1226, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 719, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 407, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/OJqfBhEXm5'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'CR7underwear.com',
#      u'expanded_url': u'http://CR7underwear.com',
#      u'indices': [32, 54],
#      u'url': u'http://t.co/Ns7j14SIrW'}],
#    u'user_mentions': []},
#   u'favorite_count': 4259,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 410836999906410496,
#   u'id_str': u'410836999906410496',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 4377,
#   u'retweeted': False,
#   u'source': u'web',
#   u'text': u'As an early Xmas present, visit http://t.co/Ns7j14SIrW to win some of my #CR7underwear collection favourite pieces. http://t.co/OJqfBhEXm5',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Wed Dec 11 13:25:06 +0000 2013',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/lB9AFFol81',
#      u'expanded_url': u'http://twitter.com/Cristiano/status/410762165633974272/photo/1',
#      u'id': 410762165394866176,
#      u'id_str': u'410762165394866176',
#      u'indices': [69, 91],
#      u'media_url': u'http://pbs.twimg.com/media/BbNSA1uIAAAkIl1.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/BbNSA1uIAAAkIl1.jpg',
#      u'sizes': {u'large': {u'h': 407, u'resize': u'fit', u'w': 636},
#       u'medium': {u'h': 384, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 218, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/lB9AFFol81'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': []},
#   u'favorite_count': 6870,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 410762165633974272,
#   u'id_str': u'410762165633974272',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 8006,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'Hi guys. Group stage is done, now looking forward to the next round. http://t.co/lB9AFFol81',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Dec 10 13:10:16 +0000 2013',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/JYR7g31g8X',
#      u'expanded_url': u'http://twitter.com/Cristiano/status/410396045496303616/photo/1',
#      u'id': 410396044913278976,
#      u'id_str': u'410396044913278976',
#      u'indices': [74, 96],
#      u'media_url': u'http://pbs.twimg.com/media/BbIFB0pIAAAXJIl.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/BbIFB0pIAAAXJIl.jpg',
#      u'sizes': {u'large': {u'h': 834, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 488, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 277, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/JYR7g31g8X'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': []},
#   u'favorite_count': 6386,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 410396045496303616,
#   u'id_str': u'410396045496303616',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 8965,
#   u'retweeted': False,
#   u'source': u'<a href="http://www.vivaronaldo.com" rel="nofollow">Viva Ronaldo</a>',
#   u'text': u"Tonight another game on the Champions League. Let's go team! Hala Madrid! http://t.co/JYR7g31g8X",
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Mon Dec 09 12:51:40 +0000 2013',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/ZT91AUsO5D',
#      u'expanded_url': u'http://twitter.com/Cristiano/status/410028976124346368/photo/1',
#      u'id': 410028976128540672,
#      u'id_str': u'410028976128540672',
#      u'indices': [79, 101],
#      u'media_url': u'http://pbs.twimg.com/media/BbC3Lm3CQAAZmfO.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/BbC3Lm3CQAAZmfO.jpg',
#      u'sizes': {u'large': {u'h': 407, u'resize': u'fit', u'w': 636},
#       u'medium': {u'h': 384, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 218, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/ZT91AUsO5D'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': []},
#   u'favorite_count': 6436,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 410028976124346368,
#   u'id_str': u'410028976124346368',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 7183,
#   u'retweeted': False,
#   u'source': u'web',
#   u'text': u'Hey guys, we arrived in Copenhagen for another Champions League game tomorrow! http://t.co/ZT91AUsO5D',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Dec 05 22:44:49 +0000 2013',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/IA72uYB6N4',
#      u'expanded_url': u'http://twitter.com/Cristiano/status/408728693834776576/photo/1',
#      u'id': 408728693658640384,
#      u'id_str': u'408728693658640384',
#      u'indices': [78, 100],
#      u'media_url': u'http://pbs.twimg.com/media/BawYlNMIYAA1spF.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/BawYlNMIYAA1spF.jpg',
#      u'sizes': {u'large': {u'h': 594, u'resize': u'fit', u'w': 401},
#       u'medium': {u'h': 594, u'resize': u'fit', u'w': 401},
#       u'small': {u'h': 504, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/IA72uYB6N4'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': []},
#   u'favorite_count': 25329,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 408728693834776576,
#   u'id_str': u'408728693834776576',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 43903,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'Thankful Madiba for your legacy and your example. You"ll always stay with us. http://t.co/IA72uYB6N4',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Dec 05 17:12:13 +0000 2013',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/qbYhuC46yk',
#      u'expanded_url': u'http://twitter.com/Cristiano/status/408644995306901504/photo/1',
#      u'id': 408644995315290112,
#      u'id_str': u'408644995315290112',
#      u'indices': [87, 109],
#      u'media_url': u'http://pbs.twimg.com/media/BavMdUkCUAAYtGH.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/BavMdUkCUAAYtGH.jpg',
#      u'sizes': {u'large': {u'h': 838, u'resize': u'fit', u'w': 1024},
#       u'medium': {u'h': 491, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 278, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/qbYhuC46yk'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'bit.ly/TheGAMErank',
#      u'expanded_url': u'http://bit.ly/TheGAMErank',
#      u'indices': [19, 41],
#      u'url': u'http://t.co/hgrrSmfQzG'}],
#    u'user_mentions': []},
#   u'favorite_count': 3028,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 408644995306901504,
#   u'id_str': u'408644995306901504',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 3146,
#   u'retweeted': False,
#   u'source': u'web',
#   u'text': u'Check the rankings http://t.co/hgrrSmfQzG, spread the word, lead your city to the top! http://t.co/qbYhuC46yk',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Dec 05 15:30:36 +0000 2013',
#   u'entities': {u'hashtags': [{u'indices': [85, 99],
#      u'text': u'GAMEbyRonaldo'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': []},
#   u'favorite_count': 1543,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 408619423470088192,
#   u'id_str': u'408619423470088192',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'retweet_count': 1747,
#   u'retweeted': False,
#   u'source': u'web',
#   u'text': u'Help your city reach 100 ready teams (with 5 players or more) and start competing in #GAMEbyRonaldo right away.',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Dec 03 23:43:11 +0000 2013',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/ZCDBMTPfjd',
#      u'expanded_url': u'http://twitter.com/Cristiano/status/408018607789314048/photo/1',
#      u'id': 408018607625744385,
#      u'id_str': u'408018607625744385',
#      u'indices': [53, 75],
#      u'media_url': u'http://pbs.twimg.com/media/BamSwwlIMAE2f_u.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/BamSwwlIMAE2f_u.jpg',
#      u'sizes': {u'large': {u'h': 427, u'resize': u'fit', u'w': 640},
#       u'medium': {u'h': 400, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 227, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/ZCDBMTPfjd'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': []},
#   u'favorite_count': 7444,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 408018607789314048,
#   u'id_str': u'408018607789314048',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 5710,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'Enjoyable dinner with family and friends in Madeira. http://t.co/ZCDBMTPfjd',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Dec 03 10:41:14 +0000 2013',
#   u'entities': {u'hashtags': [],
#    u'media': [{u'display_url': u'pic.twitter.com/fjI7lvOKvc',
#      u'expanded_url': u'http://twitter.com/Cristiano/status/407821822084669440/photo/1',
#      u'id': 407821822093058049,
#      u'id_str': u'407821822093058049',
#      u'indices': [116, 138],
#      u'media_url': u'http://pbs.twimg.com/media/BajfyVWCYAEQlXa.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/BajfyVWCYAEQlXa.jpg',
#      u'sizes': {u'large': {u'h': 409, u'resize': u'fit', u'w': 640},
#       u'medium': {u'h': 383, u'resize': u'fit', u'w': 600},
#       u'small': {u'h': 217, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/fjI7lvOKvc'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': []},
#   u'favorite_count': 7720,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 407821822084669440,
#   u'id_str': u'407821822084669440',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 10535,
#   u'retweeted': False,
#   u'source': u'web',
#   u'text': u'It\u2019s an honour and a privilege to receive the award of Liga de F\xfatbol Professional Most Valuable Player of 2012/13. http://t.co/fjI7lvOKvc',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Mon Dec 02 15:35:02 +0000 2013',
#   u'entities': {u'hashtags': [{u'indices': [36, 48], u'text': u'VivaRonaldo'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'is.gd/l5XJrT',
#      u'expanded_url': u'http://is.gd/l5XJrT',
#      u'indices': [115, 137],
#      u'url': u'http://t.co/T4MFXRudoZ'}],
#    u'user_mentions': [{u'id': 472428172,
#      u'id_str': u'472428172',
#      u'indices': [12, 24],
#      u'name': u'Viva Ronaldo',
#      u'screen_name': u'VivaRonaldo'}]},
#   u'favorite_count': 1797,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 407533375130316800,
#   u'id_str': u'407533375130316800',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 2391,
#   u'retweeted': False,
#   u'source': u'web',
# ...
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Fri Oct 25 11:05:46 +0000 2013',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 579930293,
#      u'id_str': u'579930293',
#      u'indices': [0, 9],
#      u'name': u"Dana' Ronaldo\u2661",
#      u'screen_name': u'_xDANAx_'}]},
#   u'favorite_count': 181,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 393694871258533890,
#   u'id_str': u'393694871258533890',
#   u'in_reply_to_screen_name': u'_xDANAx_',
#   u'in_reply_to_status_id': 393688487570182144,
#   u'in_reply_to_status_id_str': u'393688487570182144',
#   u'in_reply_to_user_id': 579930293,
#   u'in_reply_to_user_id_str': u'579930293',
#   u'lang': u'en',
#   u'place': None,
#   u'retweet_count': 124,
#   u'retweeted': False,
#   u'source': u'web',
#   u'text': u'@_xDANAx_ Hello, good morning. How are you doing?',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Fri Oct 25 10:03:47 +0000 2013',
#   u'entities': {u'hashtags': [{u'indices': [55, 65], u'text': u'Mercurial'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'go.nike.com/2hinjnl',
#      u'expanded_url': u'http://go.nike.com/2hinjnl',
#      u'indices': [80, 102],
#      u'url': u'http://t.co/VWNasM50Ht'},
#     {u'display_url': u'youtu.be/q_5KpxNwlYk',
#      u'expanded_url': u'http://youtu.be/q_5KpxNwlYk',
#      u'indices': [103, 125],
#      u'url': u'http://t.co/qScJiRlJwc'}],
#    u'user_mentions': []},
#   u'favorite_count': 1804,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 393679274776883201,
#   u'id_str': u'393679274776883201',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 2977,
#   u'retweeted': False,
#   u'source': u'web',
#   u'text': u'I play in the moment. Sometimes I even surprise myself #Mercurial  :)  \nEurope: http://t.co/VWNasM50Ht http://t.co/qScJiRlJwc',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Oct 24 14:20:27 +0000 2013',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 610303916,
#      u'id_str': u'610303916',
#      u'indices': [0, 9],
#      u'name': u'baharRonaldo7',
#      u'screen_name': u'baharCR7'}]},
#   u'favorite_count': 240,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 393381475724165120,
#   u'id_str': u'393381475724165120',
#   u'in_reply_to_screen_name': u'baharCR7',
#   u'in_reply_to_status_id': 393348909365747712,
#   u'in_reply_to_status_id_str': u'393348909365747712',
#   u'in_reply_to_user_id': 610303916,
#   u'in_reply_to_user_id_str': u'610303916',
#   u'lang': u'en',
#   u'place': None,
#   u'retweet_count': 160,
#   u'retweeted': False,
#   u'source': u'web',
#   u'text': u'@baharCR7 Of course! A big hello to you.',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Oct 24 14:20:05 +0000 2013',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 127917389,
#      u'id_str': u'127917389',
#      u'indices': [0, 15],
#      u'name': u'Juan Felipe C',
#      u'screen_name': u'juanfecaceresr'}]},
#   u'favorite_count': 319,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 393381382904233984,
#   u'id_str': u'393381382904233984',
#   u'in_reply_to_screen_name': u'juanfecaceresr',
#   u'in_reply_to_status_id': 393355459203440641,
#   u'in_reply_to_status_id_str': u'393355459203440641',
#   u'in_reply_to_user_id': 127917389,
#   u'in_reply_to_user_id_str': u'127917389',
#   u'lang': u'es',
#   u'place': None,
#   u'retweet_count': 290,
#   u'retweeted': False,
#   u'source': u'web',
#   u'text': u'@juanfecaceresr Hola Colombia.',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Thu Oct 24 14:19:41 +0000 2013',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 799068823,
#      u'id_str': u'799068823',
#      u'indices': [0, 13],
#      u'name': u'F',
#      u'screen_name': u'FuadFathalla'}]},
#   u'favorite_count': 183,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 393381283738300416,
#   u'id_str': u'393381283738300416',
#   u'in_reply_to_screen_name': u'FuadFathalla',
#   u'in_reply_to_status_id': 393355643643379712,
#   u'in_reply_to_status_id_str': u'393355643643379712',
#   u'in_reply_to_user_id': 799068823,
#   u'in_reply_to_user_id_str': u'799068823',
#   u'lang': u'en',
#   u'place': None,
#   u'retweet_count': 116,
#   u'retweeted': False,
#   u'source': u'web',
#   u'text': u'@FuadFathalla That\u2019s true, another big game coming up on Saturday.',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#    u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#        u'expanded_url': u'http://bit.ly/YK8D4q',
#        u'indices': [79, 101],
#        u'url': u'http://t.co/UA9BjJfseB'}]},
#     u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#        u'expanded_url': u'http://www.facebook.com/cristiano',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/TveKjB37vk'}]}},
#    u'favourites_count': 0,
#    u'follow_request_sent': False,
#    u'followers_count': 23252854,
#    u'following': True,
#    u'friends_count': 83,
#    u'geo_enabled': False,
#    u'id': 155659213,
#    u'id_str': u'155659213',
#    u'is_translator': False,
#    u'lang': u'pt',
#    u'listed_count': 74481,
#    u'location': u'Madrid',
#    u'name': u'Cristiano Ronaldo',
#    u'notifications': False,
#    u'profile_background_color': u'080101',
#    u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#    u'profile_link_color': u'1643C9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'838387',
#    u'profile_text_color': u'0D0D0D',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Cristiano',
#    u'statuses_count': 1670,
#    u'time_zone': u'Madrid',
#    u'url': u'http://t.co/TveKjB37vk',
#    u'utc_offset': 3600,
#    u'verified': True}}]

# %%
search_results[0]
# Out:
# {u'contributors': None,
#  u'coordinates': None,
#  u'created_at': u'Fri Dec 13 18:07:45 +0000 2013',
#  u'entities': {u'hashtags': [{u'indices': [39, 48], u'text': u'GALAXY11'}],
#   u'symbols': [],
#   u'urls': [{u'display_url': u'youtu.be/86wGkXjgEjI',
#     u'expanded_url': u'http://youtu.be/86wGkXjgEjI',
#     u'indices': [115, 137],
#     u'url': u'http://t.co/TCTSzsPOcn'}],
#   u'user_mentions': []},
#  u'favorite_count': 292,
#  u'favorited': False,
#  u'geo': None,
#  u'id': 411558072017231872,
#  u'id_str': u'411558072017231872',
#  u'in_reply_to_screen_name': None,
#  u'in_reply_to_status_id': None,
#  u'in_reply_to_status_id_str': None,
#  u'in_reply_to_user_id': None,
#  u'in_reply_to_user_id_str': None,
#  u'lang': u'en',
#  u'place': None,
#  u'possibly_sensitive': False,
#  u'retweet_count': 437,
#  u'retweeted': False,
#  u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  u'text': u"The Alien threat is here - I've joined #GALAXY11 to play football in space and defend this planet that we love...\xa0\nhttp://t.co/TCTSzsPOcn",
#  u'truncated': False,
#  u'user': {u'contributors_enabled': False,
#   u'created_at': u'Mon Jun 14 19:09:20 +0000 2010',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB',
#   u'entities': {u'description': {u'urls': [{u'display_url': u'bit.ly/YK8D4q',
#       u'expanded_url': u'http://bit.ly/YK8D4q',
#       u'indices': [79, 101],
#       u'url': u'http://t.co/UA9BjJfseB'}]},
#    u'url': {u'urls': [{u'display_url': u'facebook.com/cristiano',
#       u'expanded_url': u'http://www.facebook.com/cristiano',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/TveKjB37vk'}]}},
#   u'favourites_count': 0,
#   u'follow_request_sent': False,
#   u'followers_count': 23252854,
#   u'following': True,
#   u'friends_count': 83,
#   u'geo_enabled': False,
#   u'id': 155659213,
#   u'id_str': u'155659213',
#   u'is_translator': False,
#   u'lang': u'pt',
#   u'listed_count': 74481,
#   u'location': u'Madrid',
#   u'name': u'Cristiano Ronaldo',
#   u'notifications': False,
#   u'profile_background_color': u'080101',
#   u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#   u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/155659213/1382178472',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg',
#   u'profile_link_color': u'1643C9',
#   u'profile_sidebar_border_color': u'FFFFFF',
#   u'profile_sidebar_fill_color': u'838387',
#   u'profile_text_color': u'0D0D0D',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'Cristiano',
#   u'statuses_count': 1670,
#   u'time_zone': u'Madrid',
#   u'url': u'http://t.co/TveKjB37vk',
#   u'utc_offset': 3600,
#   u'verified': True}}

# %%
print json.dumps(search_results[0], indent=1)
# Out:
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "The Alien threat is here - I've joined #GALAXY11 to play football in space and defend this planet that we love...\u00a0\nhttp://t.co/TCTSzsPOcn",
#  "in_reply_to_status_id": null,
#  "id": 411558072017231872,
#  "favorite_count": 292,
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "retweeted": false,
#  "coordinates": null,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [],
#   "hashtags": [
#    {
#     "indices": [
#      39,
#      48
#     ],
#     "text": "GALAXY11"
#    }
#   ],
#   "urls": [
#    {
#     "url": "http://t.co/TCTSzsPOcn",
#     "indices": [
#      115,
#      137
#     ],
#     "expanded_url": "http://youtu.be/86wGkXjgEjI",
#     "display_url": "youtu.be/86wGkXjgEjI"
#    }
#   ]
#  },
#  "in_reply_to_screen_name": null,
#  "id_str": "411558072017231872",
#  "retweet_count": 437,
#  "in_reply_to_user_id": null,
#  "favorited": false,
#  "user": {
#   "follow_request_sent": false,
#   "profile_use_background_image": true,
#   "default_profile_image": false,
#   "id": 155659213,
#   "verified": true,
#   "profile_text_color": "0D0D0D",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg",
#   "profile_sidebar_fill_color": "838387",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "http://t.co/TveKjB37vk",
#       "indices": [
#        0,
#        22
#       ],
#       "expanded_url": "http://www.facebook.com/cristiano",
#       "display_url": "facebook.com/cristiano"
#      }
#     ]
#    },
#    "description": {
#     "urls": [
#      {
#       "url": "http://t.co/UA9BjJfseB",
#       "indices": [
#        79,
#        101
#       ],
#       "expanded_url": "http://bit.ly/YK8D4q",
#       "display_url": "bit.ly/YK8D4q"
#      }
#     ]
#    }
#   },
#   "followers_count": 23252854,
#   "profile_sidebar_border_color": "FFFFFF",
#   "id_str": "155659213",
#   "profile_background_color": "080101",
#   "listed_count": 74481,
#   "profile_background_image_url_https": "https://si0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg",
#   "utc_offset": 3600,
#   "statuses_count": 1670,
#   "description": "This Privacy Policy addresses the collection and use of personal information - http://t.co/UA9BjJfseB",
#   "friends_count": 83,
#   "location": "Madrid",
#   "profile_link_color": "1643C9",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/378800000766289614/c6644f181db4695ed0f90b8c499538e3_normal.jpeg",
#   "following": true,
#   "geo_enabled": false,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/155659213/1382178472",
#   "profile_background_image_url": "http://a0.twimg.com/profile_background_images/378800000097670002/b4d38f78d58f3c0d8536f273355d59fd.jpeg",
#   "screen_name": "Cristiano",
#   "lang": "pt",
#   "profile_background_tile": false,
#   "favourites_count": 0,
#   "name": "Cristiano Ronaldo",
#   "notifications": false,
#   "url": "http://t.co/TveKjB37vk",
#   "created_at": "Mon Jun 14 19:09:20 +0000 2010",
#   "contributors_enabled": false,
#   "time_zone": "Madrid",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": null,
#  "possibly_sensitive": false,
#  "lang": "en",
#  "created_at": "Fri Dec 13 18:07:45 +0000 2013",
#  "in_reply_to_status_id_str": null,
#  "place": null
# }

# %%
search_results[0]['id']
# Out:
# 411558072017231872

# %%
ret= twitter_api.statuses.retweets.id(id = 411558072017231872, count = 11)

# %%
ret[3]['user']['id']
# Out:
# 930225476

# %%
ret[3]['user']['screen_name']
# Out:
# u'oisincelada97'

# %%
user = twitter_api.users.show(user_id=930225476,screen_name='oisincelada97')

# %%
ret[2]['user']
# Out:
# {u'contributors_enabled': False,
#  u'created_at': u'Mon Apr 18 16:46:19 +0000 2011',
#  u'default_profile': True,
#  u'default_profile_image': False,
#  u'description': u'@juventusfc colaborate with @BondanF2B',
#  u'entities': {u'description': {u'urls': []}},
#  u'favourites_count': 1,
#  u'follow_request_sent': False,
#  u'followers_count': 56,
#  u'following': False,
#  u'friends_count': 154,
#  u'geo_enabled': False,
#  u'id': 284104926,
#  u'id_str': u'284104926',
#  u'is_translator': False,
#  u'lang': u'en',
#  u'listed_count': 0,
#  u'location': u'Bandung, INDONESIA',
#  u'name': u'mr. blackwhitestrip',
#  u'notifications': False,
#  u'profile_background_color': u'C0DEED',
#  u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#  u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#  u'profile_background_tile': False,
#  u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/284104926/1382507970',
#  u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000838124637/14c76dfb04aebe2982280b8213c1c488_normal.jpeg',
#  u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000838124637/14c76dfb04aebe2982280b8213c1c488_normal.jpeg',
#  u'profile_link_color': u'0084B4',
#  u'profile_sidebar_border_color': u'C0DEED',
#  u'profile_sidebar_fill_color': u'DDEEF6',
#  u'profile_text_color': u'333333',
#  u'profile_use_background_image': True,
#  u'protected': False,
#  u'screen_name': u'rezpector_86',
#  u'statuses_count': 1128,
#  u'time_zone': None,
#  u'url': None,
#  u'utc_offset': None,
#  u'verified': False}

# %%
for i in range(len(ret)):
    if ret[i]['user']['location']:
        print ret[i]['user']['location']
# Out:
# Madrid & Cris Home!
# Ebano S.L.P (Mexico)
# Bandung, INDONESIA
# TX
# Behind U
# Las Bayas - Elche

# %%
screen_name = 'BarackObama'
user = twitter_api.users.show(screen_name=screen_name)
user_id = user['id']

# %%
user
# Out:
# {u'contributors_enabled': False,
#  u'created_at': u'Mon Mar 05 22:08:25 +0000 2007',
#  u'default_profile': False,
#  u'default_profile_image': False,
#  u'description': u'This account is run by Organizing for Action staff. Tweets from the President are signed -bo.',
#  u'entities': {u'description': {u'urls': []},
#   u'url': {u'urls': [{u'display_url': u'barackobama.com',
#      u'expanded_url': u'http://www.barackobama.com',
#      u'indices': [0, 22],
#      u'url': u'http://t.co/8aJ56Jcemr'}]}},
#  u'favourites_count': 3,
#  u'follow_request_sent': False,
#  u'followers_count': 40495491,
#  u'following': True,
#  u'friends_count': 655275,
#  u'geo_enabled': False,
#  u'id': 813286,
#  u'id_str': u'813286',
#  u'is_translator': False,
#  u'lang': u'en',
#  u'listed_count': 201997,
#  u'location': u'Washington, DC',
#  u'name': u'Barack Obama',
#  u'notifications': False,
#  u'profile_background_color': u'77B0DC',
#  u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000096573600/b899990be08dee6857c5166b43589c5c.png',
#  u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000096573600/b899990be08dee6857c5166b43589c5c.png',
#  u'profile_background_tile': False,
#  u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/813286/1360123769',
#  u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000607588261/dad9f009a228a78a14f1f4bed0c54f76_normal.png',
#  u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000607588261/dad9f009a228a78a14f1f4bed0c54f76_normal.png',
#  u'profile_link_color': u'2574AD',
#  u'profile_sidebar_border_color': u'FFFFFF',
#  u'profile_sidebar_fill_color': u'C2E0F6',
#  u'profile_text_color': u'333333',
#  u'profile_use_background_image': True,
#  u'protected': False,
#  u'screen_name': u'BarackObama',
#  u'status': {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Fri Dec 13 18:28:22 +0000 2013',
#   u'entities': {u'hashtags': [],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'OFA.BO/Kwa9Sq',
#      u'expanded_url': u'http://OFA.BO/Kwa9Sq',
#      u'indices': [105, 127],
#      u'url': u'http://t.co/OYo43dqYt2'}],
#    u'user_mentions': []},
#   u'favorite_count': 314,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 411563262233157633,
#   u'id_str': u'411563262233157633',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 436,
#   u'retweeted': False,
#   u'source': u'web',
#   u'text': u'May your days be merry and bright, and may your Christmas include a conversation about health insurance. http://t.co/OYo43dqYt2',
#   u'truncated': False},
#  u'statuses_count': 10555,
#  u'time_zone': u'Eastern Time (US & Canada)',
#  u'url': u'http://t.co/8aJ56Jcemr',
#  u'utc_offset': -18000,
#  u'verified': True}

# %%
user_id
# Out:
# 813286

# %%
screen_name = 'BarackObama'
user = twitter_api.users.show(screen_name=screen_name)
user_id = user['id']
tweets_count = 100

user_tweets = twitter_api.statuses.user_timeline(user_id = user_id, screen_name = screen_name, count = tweets_count)

user_hot_tweets = []

for i in range(user_tweets):
	if user_tweets[i]['retweet_count']>10000:
		user_hot_tweets.append(user_tweets[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-bad1b3dd0fc5> in <module>()
#       8 user_hot_tweets = []
#       9
# ---> 10 for i in range(user_tweets):
#      11         if user_tweets[i]['retweet_count']>10000:
#      12                 user_hot_tweets.append(user_tweets[i])
#
# TypeError: range() integer end argument expected, got WrappedTwitterResponse.

# %%
screen_name = 'BarackObama'
user = twitter_api.users.show(screen_name=screen_name)
user_id = user['id']
tweets_count = 100

user_tweets = twitter_api.statuses.user_timeline(user_id = user_id, screen_name = screen_name, count = tweets_count)

user_hot_tweets = []

for i in range(len(user_tweets)):
	if user_tweets[i]['retweet_count']>10000:
		user_hot_tweets.append(user_tweets[i])

# %%
len(user_hot_tweets)
# Out:
# 3

# %%
for i in range(len(user_hot_tweets)):
	print user_hot_tweets[i]['id']
# Out:
# 408733159090421762
# 408730399276154880
# 407256240570396672

# %%
retweets = twitter_api.statuses.retweets.id(id = hot_tweet_id, count = tweets_count)
for i in range(len(retweets)):
	retweets[i]['user']['id']
	retweets[i]['user']['screen_name']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-feedf2bdc916> in <module>()
# ----> 1 retweets = twitter_api.statuses.retweets.id(id = hot_tweet_id, count = tweets_count)
#       2 for i in range(len(retweets)):
#       3         retweets[i]['user']['id']
#       4         retweets[i]['user']['screen_name']
#
# NameError: name 'hot_tweet_id' is not defined

# %%
hot_tweet_id = user_hot_tweets[0]['id']
retweets = twitter_api.statuses.retweets.id(id = hot_tweet_id, count = tweets_count)
for i in range(len(retweets)):
	retweets[i]['user']['id']
	retweets[i]['user']['screen_name']

# %%
for i in range(len(retweets)):
	 if retweets[i]['user']['location']:
            print retweets[i]['user']['location']
# Out:
# Mumbai
# New Zealand
# Kingston,jamaica
# Perú
# Atl, DC, Chi, LA, NY, Miami
# Rosie's bed
# Ratanda,Heidelberg
# Panama City
# South Africa, PMB
# Europe- LA - Nyc-Chicago
# Cape Town, South Africa
# Cape Town, SA
# Lille
# Playing center back
# London
# Insta/anisahuddin
# Provo, Utah
# Bergville, KwaZulu Natal
# Denver! (:
# British Columbia, Canada
# Vaal-South Africa
# Where Eclectic Griots Meet
# wash dc 17 th SE out here!
# NYC
# roanoke va
# them states
# All Around The World...
# 2/4+band acc.
# North-West & South-East London
# cape town, South Africa
# South Africa
# South Africa
#  lalalalalalalalala girl
# Lyon, France
# Cape Town South Africa
# Gombak, Selangor
# St.Albans, England
# the world
# Norway
# Edmonton, Alberta, Canada
# Denmark
# Pta
# Lexington/Bentonville
# New England
# Malaysia
# South of France. (30. gard)
# Los Angeles, CA
# PRETORIA
# iPhone: 51.458374,-0.186446
# MALLORCA 4EVER AND EVER
# Adelaide, Australia
# Camp Half BloodΨ
# ÜT: 40.755086,-74.005111
# Cape Town/Durban
#  Narnia,Panem,Hogwarts y Forks
# South Africa
# idk
# 99% my head 1% wellington
# Sydney
# Made in NZ
# In the beginning of happiness.
# Toronto, Canada
# Joburg, South Africa
# À Procura de Nemo

# %%
user_hot_tweets[0]
# Out:
# {u'contributors': None,
#  u'coordinates': None,
#  u'created_at': u'Thu Dec 05 23:02:33 +0000 2013',
#  u'entities': {u'hashtags': [],
#   u'symbols': [],
#   u'urls': [],
#   u'user_mentions': []},
#  u'favorite_count': 19935,
#  u'favorited': False,
#  u'geo': None,
#  u'id': 408733159090421762,
#  u'id_str': u'408733159090421762',
#  u'in_reply_to_screen_name': None,
#  u'in_reply_to_status_id': None,
#  u'in_reply_to_status_id_str': None,
#  u'in_reply_to_user_id': None,
#  u'in_reply_to_user_id_str': None,
#  u'lang': u'en',
#  u'place': None,
#  u'retweet_count': 40334,
#  u'retweeted': False,
#  u'source': u'web',
#  u'text': u'"Let us pause and give thanks for the fact that Nelson Mandela lived." \u2014President Obama',
#  u'truncated': False,
#  u'user': {u'contributors_enabled': False,
#   u'created_at': u'Mon Mar 05 22:08:25 +0000 2007',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'This account is run by Organizing for Action staff. Tweets from the President are signed -bo.',
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'barackobama.com',
#       u'expanded_url': u'http://www.barackobama.com',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/8aJ56Jcemr'}]}},
#   u'favourites_count': 3,
#   u'follow_request_sent': False,
#   u'followers_count': 40495931,
#   u'following': True,
#   u'friends_count': 655275,
#   u'geo_enabled': False,
#   u'id': 813286,
#   u'id_str': u'813286',
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 202000,
#   u'location': u'Washington, DC',
#   u'name': u'Barack Obama',
#   u'notifications': False,
#   u'profile_background_color': u'77B0DC',
#   u'profile_background_image_url': u'http://a0.twimg.com/profile_background_images/378800000096573600/b899990be08dee6857c5166b43589c5c.png',
#   u'profile_background_image_url_https': u'https://si0.twimg.com/profile_background_images/378800000096573600/b899990be08dee6857c5166b43589c5c.png',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/813286/1360123769',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000607588261/dad9f009a228a78a14f1f4bed0c54f76_normal.png',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000607588261/dad9f009a228a78a14f1f4bed0c54f76_normal.png',
#   u'profile_link_color': u'2574AD',
#   u'profile_sidebar_border_color': u'FFFFFF',
#   u'profile_sidebar_fill_color': u'C2E0F6',
#   u'profile_text_color': u'333333',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'BarackObama',
#   u'statuses_count': 10555,
#   u'time_zone': u'Eastern Time (US & Canada)',
#   u'url': u'http://t.co/8aJ56Jcemr',
#   u'utc_offset': -18000,
#   u'verified': True}}

# %%
user_tweets = twitter_api.statuses.user_timeline(screen_name = screen_name, count = tweets_count)

# %%
user_tweets[0]['user']['id']
# Out:
# 813286

# %%
for i in range(len(user_tweets)):
	if user_tweets[i]['retweet_count']>10000:
		needed_tweets_info = {}
		needed_tweets_info['tweet_id'] = user_tweets[i]['id']
		needed_tweets_info['text'] = user_tweets[i]['text']
        needed_tweets_info['profile_pic']=user_tweets[i]['user']['profile_image_url']
        needed_tweets_info['screen_name']=user_tweets[i]['user']['screen_name']
        user_hot_tweets.append(needed_tweets_info)

# %%
len(user_hot_tweets)
# Out:
# 106

# %%
user_hot_tweets[100]
# Out:
# {'profile_pic': u'http://pbs.twimg.com/profile_images/378800000607588261/dad9f009a228a78a14f1f4bed0c54f76_normal.png',
#  'screen_name': u'BarackObama',
#  'text': u'President Obama remembers Nelson Mandela: "A man who took history in his hands and bent the arc of the moral universe towards justice."',
#  'tweet_id': 408730399276154880}

# %%
import twitter
import json, ast
from collections import Counter, defaultdict

import matplotlib.pyplot as plt

CONSUMER_KEY = '9WQ8uPw0E6XjnN5Fpe4wQ'
CONSUMER_SECRET = 'eqRTSHzkDUe78lKLShsX7YvaecUaonr5xkglyFxEhEc'
OAUTH_TOKEN = '931200800-vVarLuafor9AAyrQ7Q3RHS0QOJux5WUw67QLLgyk'
OAUTH_TOKEN_SECRET = 'KSKyxgV6ucWqUvwmuVDYfJbZlenA83AYnVWlx1kBxONSn'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)
twitter_api = twitter.Twitter(auth=auth)

#Collect search results
# XXX: Set this variable to a trending topic, or anything else for that matter.
q = '#manunited'
user_id = '813286'
screen_name = 'BarackObama'
count = 200
index = 0
retweet_id_array = []
search_results = twitter_api.statuses.user_timeline(user_id = user_id, screen_name = screen_name, count = count)
#search_results = twitter_api.search.tweets(q = q, count = count)
#statuses = search_results['statuses']
for tweet in search_results:
	while index < count:
		retweet_count = search_results[index]['retweet_count']
		if(retweet_count > 10000):
			retweet_id = search_results[index]['id']
			retweet_id_array.append(retweet_id)
		index += 1

total = []
#get retweeter_id, location, screen_name, profile_picture
for i in range(len(retweet_id_array)):
	get_retweet = twitter_api.statuses.retweets.id(id = retweet_id_array[i], count = 100)
	for index_retweeter in range(len(get_retweet)):
		needed_tweets_info = {}
		if(get_retweet[index_retweeter]['user']['location'] == ''): continue
		needed_tweets_info['tweet_id'] = get_retweet[index_retweeter]['id']
		needed_tweets_info['create_time'] = get_retweet[index_retweeter]['created_at']
		needed_tweets_info['retweeter_id'] = get_retweet[index_retweeter]['user']['id']
		needed_tweets_info['text'] = get_retweet[index_retweeter]['user']['description']
		needed_tweets_info['profile_pic'] = get_retweet[index_retweeter]['user']['profile_image_url']
		needed_tweets_info['screen_name'] = get_retweet[index_retweeter]['user']['screen_name']
		needed_tweets_info['location'] = get_retweet[index_retweeter]['user']['location']
		total.append(needed_tweets_info)
	total_info.append({retweet_id_array[i] : total})
#total_info = dict((1, tuple(needed_tweets_info)) for 1, needed_tweets_info in total.iteritems())
print ast.literal_eval(json.dumps(total_info))
# Out:
# {'407256240570396672': [{'profile_pic': 'http://pbs.twimg.com/profile_images/378800000627445735/ce301fae3f1027e9c0316c9bf0bf7cce_normal.jpeg', 'screen_name': 'ErinJoyd', 'text': 'Follow your dreams\\u2323\\u030a\\u2508\\u0325-\\u0336\\u032f\\u0361\\u2648\\u0337\\u0334\\u2606 Saw @Rihanna Live #DiamondsWorldTour concert 16.10.13', 'tweet_id': 411965401367859201, 'create_time': 'Sat Dec 14 21:06:20 +0000 2013', 'location': 'Cape Town, South Africa', 'retweeter_id': 298863699}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000811569512/8981dbf21bf5617daa58a7cb62e4f615_normal.jpeg', 'screen_name': 'swageeta_', 'text': "psychology student at strathclyde uni. 18. Don't hate, meditate.", 'tweet_id': 411915688073519104, 'create_time': 'Sat Dec 14 17:48:47 +0000 2013', 'location': 'Glasgow, Scotland.', 'retweeter_id': 58586363}, {'profile_pic': 'http://pbs.twimg.com/profile_images/411945551085584384/Z4HSWagc_normal.jpeg', 'screen_name': 'janostarbuck', 'text': "sorry i'm not good at peopleing", 'tweet_id': 411895135103123457, 'create_time': 'Sat Dec 14 16:27:07 +0000 2013', 'location': '@awesomebiebz @arianadrewlloyd', 'retweeter_id': 621831094}, {'profile_pic': 'http://pbs.twimg.com/profile_images/411856720420278272/SLhqLJxV_normal.jpeg', 'screen_name': 'Gina_Laura_Mai', 'text': 'http://t.co/ZGaWF3uL3d', 'tweet_id': 411893512171700224, 'create_time': 'Sat Dec 14 16:20:40 +0000 2013', 'location': 'Mannheim; germany ', 'retweeter_id': 1267340834}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000805073264/ffa82efe7634b9e941b1d9db2c06b194_normal.jpeg', 'screen_name': 'Tobigo12', 'text': '@LFC @MiamiHEAT @RedSox @inter #SuperEagles.', 'tweet_id': 411893032556822528, 'create_time': 'Sat Dec 14 16:18:46 +0000 2013', 'location': 'PLUTO', 'retweeter_id': 180838616}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000559693706/29b602ca4f41398ef5ecd4ff82f2b7e6_normal.jpeg', 'screen_name': 'MsBappyLewis', 'text': 'R.I.P Cory Montieth/Performing Arts Student/Glee Lover/Football Fan (WBA)/Ground Hopper/Love Music/Great Personality/Follow me! I follow back! :D', 'tweet_id': 411870036291497985, 'create_time': 'Sat Dec 14 14:47:23 +0000 2013', 'location': 'Staffordshire', 'retweeter_id': 1514593261}, {'profile_pic': 'http://pbs.twimg.com/profile_images/2844070785/9d7640f83de026889f35f1d7ef99dfc4_normal.jpeg', 'screen_name': 'GOLD_555_MR', 'text': '\\u00cc\\ue32eAM M\\u0128`\\u00c7\\u0124\\u00c8L\\u00c8\\ue32fR\\u00c8\\u00d1\\u00c8` K\\u0128\\u00d1G\\ue32e.\\u2654.\\ue32eQU\\u00c8\\u00c8\\u00d1 \\u0128\\ue32eAM \\u00cc\\u2766\\u044f\\u00e9\\u0164WEE\\u0164 \\u2202\\u03c3\\u0454s\\u2766N\\u00d2Tm\\u0454\\u00e5\\u03b7 \\u00ccdis\\u00e5gree\\u2766\\u00cc\\u00e5gRee \\u00cc\\ue32eAM\\ue32e \\u2133\\u0454r\\u0454ly\\u2766\\u211b\\u0454\\u0164wee\\u0164i\\u03b7g \\ue32e\\ue131ALL\\ue131\\ue32e', 'tweet_id': 411791122160054272, 'create_time': 'Sat Dec 14 09:33:48 +0000 2013', 'location': '\\ue32e\\u00d1 \\u00d2 \\u0174\\ue32e', 'retweeter_id': 102713718}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000400309540/1cc5ad1430072dbb4e734910903058b0_normal.jpeg', 'screen_name': 'danielsetyanata', 'text': 'swiftie katycat brat navy gleek lovatic britneyarmy blackstar || Followed by her majesty @cherlloyd on 10-07-13 || instagram/line : danielsetyanata', 'tweet_id': 411707071336181761, 'create_time': 'Sat Dec 14 03:59:49 +0000 2013', 'location': 'jakarta', 'retweeter_id': 273865447}, {'profile_pic': 'http://pbs.twimg.com/profile_images/2957789797/031585d36c2cc21f82459a61f5ca30ac_normal.jpeg', 'screen_name': 'RodneyRichi', 'text': 'Just wanna do better then good enough, And I love ladies but succes is a lonely road.', 'tweet_id': 411626802906689536, 'create_time': 'Fri Dec 13 22:40:52 +0000 2013', 'location': 'Windhoek/Swakopmund/Namibia', 'retweeter_id': 306867676}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000844865409/7e45d1558666c7694d36f107ab979365_normal.jpeg', 'screen_name': 'teresacpereira', ...

# %%
len(total_info)
# Out:
# 1

# %%
import twitter
import json, ast
from collections import Counter, defaultdict
import matplotlib.pyplot as plt

CONSUMER_KEY = '9WQ8uPw0E6XjnN5Fpe4wQ'
CONSUMER_SECRET = 'eqRTSHzkDUe78lKLShsX7YvaecUaonr5xkglyFxEhEc'
OAUTH_TOKEN = '931200800-vVarLuafor9AAyrQ7Q3RHS0QOJux5WUw67QLLgyk'
OAUTH_TOKEN_SECRET = 'KSKyxgV6ucWqUvwmuVDYfJbZlenA83AYnVWlx1kBxONSn'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)
twitter_api = twitter.Twitter(auth=auth)

#Collect search results
# XXX: Set this variable to a trending topic, or anything else for that matter.
q = '#manunited'
user_id = '813286'
screen_name = 'BarackObama'
count = 200
index = 0
retweet_id_array = []
search_results = twitter_api.statuses.user_timeline(user_id = user_id, screen_name = screen_name, count = count)
#search_results = twitter_api.search.tweets(q = q, count = count)
#statuses = search_results['statuses']
for tweet in search_results:
	while index < count:
		retweet_count = search_results[index]['retweet_count']
		if(retweet_count > 10000):
			retweet_id = search_results[index]['id']
			retweet_id_array.append(retweet_id)
		index += 1

total = []
total_info = []
#get retweeter_id, location, screen_name, profile_picture
for i in range(len(retweet_id_array)):
	get_retweet = twitter_api.statuses.retweets.id(id = retweet_id_array[i], count = 100)
	for index_retweeter in range(len(get_retweet)):
		needed_tweets_info = {}
		if(get_retweet[index_retweeter]['user']['location'] == ''): continue
		needed_tweets_info['tweet_id'] = get_retweet[index_retweeter]['id']
		needed_tweets_info['create_time'] = get_retweet[index_retweeter]['created_at']
		needed_tweets_info['retweeter_id'] = get_retweet[index_retweeter]['user']['id']
		needed_tweets_info['text'] = get_retweet[index_retweeter]['user']['description']
		needed_tweets_info['profile_pic'] = get_retweet[index_retweeter]['user']['profile_image_url']
		needed_tweets_info['screen_name'] = get_retweet[index_retweeter]['user']['screen_name']
		needed_tweets_info['location'] = get_retweet[index_retweeter]['user']['location']
		total.append(needed_tweets_info)
	total_info.append({retweet_id_array[i] : total})
#total_info = dict((1, tuple(needed_tweets_info)) for 1, needed_tweets_info in total.iteritems())
print ast.literal_eval(json.dumps(total_info))
# Out:
# [{'408733159090421762': [{'profile_pic': 'http://pbs.twimg.com/profile_images/378800000627445735/ce301fae3f1027e9c0316c9bf0bf7cce_normal.jpeg', 'screen_name': 'ErinJoyd', 'text': 'Follow your dreams\\u2323\\u030a\\u2508\\u0325-\\u0336\\u032f\\u0361\\u2648\\u0337\\u0334\\u2606 Saw @Rihanna Live #DiamondsWorldTour concert 16.10.13', 'tweet_id': 411965401367859201, 'create_time': 'Sat Dec 14 21:06:20 +0000 2013', 'location': 'Cape Town, South Africa', 'retweeter_id': 298863699}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000811569512/8981dbf21bf5617daa58a7cb62e4f615_normal.jpeg', 'screen_name': 'swageeta_', 'text': "psychology student at strathclyde uni. 18. Don't hate, meditate.", 'tweet_id': 411915688073519104, 'create_time': 'Sat Dec 14 17:48:47 +0000 2013', 'location': 'Glasgow, Scotland.', 'retweeter_id': 58586363}, {'profile_pic': 'http://pbs.twimg.com/profile_images/411945551085584384/Z4HSWagc_normal.jpeg', 'screen_name': 'janostarbuck', 'text': "sorry i'm not good at peopleing", 'tweet_id': 411895135103123457, 'create_time': 'Sat Dec 14 16:27:07 +0000 2013', 'location': '@awesomebiebz @arianadrewlloyd', 'retweeter_id': 621831094}, {'profile_pic': 'http://pbs.twimg.com/profile_images/411856720420278272/SLhqLJxV_normal.jpeg', 'screen_name': 'Gina_Laura_Mai', 'text': 'http://t.co/ZGaWF3uL3d', 'tweet_id': 411893512171700224, 'create_time': 'Sat Dec 14 16:20:40 +0000 2013', 'location': 'Mannheim; germany ', 'retweeter_id': 1267340834}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000805073264/ffa82efe7634b9e941b1d9db2c06b194_normal.jpeg', 'screen_name': 'Tobigo12', 'text': '@LFC @MiamiHEAT @RedSox @inter #SuperEagles.', 'tweet_id': 411893032556822528, 'create_time': 'Sat Dec 14 16:18:46 +0000 2013', 'location': 'PLUTO', 'retweeter_id': 180838616}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000559693706/29b602ca4f41398ef5ecd4ff82f2b7e6_normal.jpeg', 'screen_name': 'MsBappyLewis', 'text': 'R.I.P Cory Montieth/Performing Arts Student/Glee Lover/Football Fan (WBA)/Ground Hopper/Love Music/Great Personality/Follow me! I follow back! :D', 'tweet_id': 411870036291497985, 'create_time': 'Sat Dec 14 14:47:23 +0000 2013', 'location': 'Staffordshire', 'retweeter_id': 1514593261}, {'profile_pic': 'http://pbs.twimg.com/profile_images/2844070785/9d7640f83de026889f35f1d7ef99dfc4_normal.jpeg', 'screen_name': 'GOLD_555_MR', 'text': '\\u00cc\\ue32eAM M\\u0128`\\u00c7\\u0124\\u00c8L\\u00c8\\ue32fR\\u00c8\\u00d1\\u00c8` K\\u0128\\u00d1G\\ue32e.\\u2654.\\ue32eQU\\u00c8\\u00c8\\u00d1 \\u0128\\ue32eAM \\u00cc\\u2766\\u044f\\u00e9\\u0164WEE\\u0164 \\u2202\\u03c3\\u0454s\\u2766N\\u00d2Tm\\u0454\\u00e5\\u03b7 \\u00ccdis\\u00e5gree\\u2766\\u00cc\\u00e5gRee \\u00cc\\ue32eAM\\ue32e \\u2133\\u0454r\\u0454ly\\u2766\\u211b\\u0454\\u0164wee\\u0164i\\u03b7g \\ue32e\\ue131ALL\\ue131\\ue32e', 'tweet_id': 411791122160054272, 'create_time': 'Sat Dec 14 09:33:48 +0000 2013', 'location': '\\ue32e\\u00d1 \\u00d2 \\u0174\\ue32e', 'retweeter_id': 102713718}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000400309540/1cc5ad1430072dbb4e734910903058b0_normal.jpeg', 'screen_name': 'danielsetyanata', 'text': 'swiftie katycat brat navy gleek lovatic britneyarmy blackstar || Followed by her majesty @cherlloyd on 10-07-13 || instagram/line : danielsetyanata', 'tweet_id': 411707071336181761, 'create_time': 'Sat Dec 14 03:59:49 +0000 2013', 'location': 'jakarta', 'retweeter_id': 273865447}, {'profile_pic': 'http://pbs.twimg.com/profile_images/2957789797/031585d36c2cc21f82459a61f5ca30ac_normal.jpeg', 'screen_name': 'RodneyRichi', 'text': 'Just wanna do better then good enough, And I love ladies but succes is a lonely road.', 'tweet_id': 411626802906689536, 'create_time': 'Fri Dec 13 22:40:52 +0000 2013', 'location': 'Windhoek/Swakopmund/Namibia', 'retweeter_id': 306867676}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000844865409/7e45d1558666c7694d36f107ab979365_normal.jpeg', 'screen_name': 'teresacpereira' ...

# %%
len(total_info)
# Out:
# 4

# %%
import twitter
import json, ast
from collections import Counter, defaultdict
import matplotlib.pyplot as plt

CONSUMER_KEY = '9WQ8uPw0E6XjnN5Fpe4wQ'
CONSUMER_SECRET = 'eqRTSHzkDUe78lKLShsX7YvaecUaonr5xkglyFxEhEc'
OAUTH_TOKEN = '931200800-vVarLuafor9AAyrQ7Q3RHS0QOJux5WUw67QLLgyk'
OAUTH_TOKEN_SECRET = 'KSKyxgV6ucWqUvwmuVDYfJbZlenA83AYnVWlx1kBxONSn'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)
twitter_api = twitter.Twitter(auth=auth)

#Collect search results
user_id = '813286'
screen_name = 'BarackObama'
count = 200
index = 0
retweet_id_array = []
search_results = twitter_api.statuses.user_timeline(user_id = user_id, screen_name = screen_name, count = count)
for tweet in search_results:
	while index < count:
		retweet_count = search_results[index]['retweet_count']
		if(retweet_count > 2000):
			retweet_id = search_results[index]['id']
			retweet_id_array.append(retweet_id)
		index += 1

#person information
person = []
person_info = []
for i in range(len(retweet_id_array)):
	get_person = twitter_api.statuses.show.id(id = retweet_id_array[i])
	needed_person_info = {}
	needed_person_info['tweet_id'] = get_person['id']
	needed_person_info['create_time'] = get_person['created_at']
	needed_person_info['text'] = get_person['text']
	needed_person_info['profile_pic'] = get_person['user']['profile_image_url']
	needed_person_info['screen_name'] = get_person['user']['screen_name']
	needed_person_info['location'] = get_person['user']['location']
	person.append(needed_person_info)
	person_info.append({"BarackObama" : person})
print ast.literal_eval(json.dumps(person_info))


#get retweeter info
total = []
total_info = []
#get retweeter_id, location, screen_name, profile_picture
for i in range(len(retweet_id_array)):
	get_retweet = twitter_api.statuses.retweets.id(id = retweet_id_array[i], count = 100)
	for index_retweeter in range(len(get_retweet)):
		needed_tweets_info = {}
		if(get_retweet[index_retweeter]['user']['location'] == ''): continue
		needed_tweets_info['tweet_id'] = get_retweet[index_retweeter]['id']
		needed_tweets_info['create_time'] = get_retweet[index_retweeter]['created_at']
		needed_tweets_info['retweeter_id'] = get_retweet[index_retweeter]['user']['id']
		needed_tweets_info['text'] = get_retweet[index_retweeter]['user']['description']
		needed_tweets_info['profile_pic'] = get_retweet[index_retweeter]['user']['profile_image_url']
		needed_tweets_info['name'] = get_retweet[index_retweeter]['user']['name']
		needed_tweets_info['screen_name'] = get_retweet[index_retweeter]['user']['screen_name']
		needed_tweets_info['location'] = get_retweet[index_retweeter]['user']['location']
		total.append(needed_tweets_info)
	total_info.append({retweet_id_array[i] : total})
print ast.literal_eval(json.dumps(total_info))
# Out:
# [{'BarackObama': [{'profile_pic': 'http://pbs.twimg.com/profile_images/378800000607588261/dad9f009a228a78a14f1f4bed0c54f76_normal.png', 'screen_name': 'BarackObama', 'text': '"Let us pause and give thanks for the fact that Nelson Mandela lived." \\u2014President Obama', 'tweet_id': 408733159090421762, 'create_time': 'Thu Dec 05 23:02:33 +0000 2013', 'location': 'Washington, DC'}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000607588261/dad9f009a228a78a14f1f4bed0c54f76_normal.png', 'screen_name': 'BarackObama', 'text': 'President Obama remembers Nelson Mandela: "A man who took history in his hands and bent the arc of the moral universe towards justice."', 'tweet_id': 408730399276154880, 'create_time': 'Thu Dec 05 22:51:35 +0000 2013', 'location': 'Washington, DC'}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000607588261/dad9f009a228a78a14f1f4bed0c54f76_normal.png', 'screen_name': 'BarackObama', 'text': 'In a single moment 58 years ago today, Rosa Parks helped change this country. http://t.co/C502SKfJnj', 'tweet_id': 407256240570396672, 'create_time': 'Sun Dec 01 21:13:49 +0000 2013', 'location': 'Washington, DC'}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000607588261/dad9f009a228a78a14f1f4bed0c54f76_normal.png', 'screen_name': 'BarackObama', 'text': "Retweet if you believe health care isn't a privilege for a fortunate few, but a right for all. #Obamacare http://t.co/NYzWBIFIOl", 'tweet_id': 402859837559545857, 'create_time': 'Tue Nov 19 18:04:04 +0000 2013', 'location': 'Washington, DC'}]}, {'BarackObama': [{'profile_pic': 'http://pbs.twimg.com/profile_images/378800000607588261/dad9f009a228a78a14f1f4bed0c54f76_normal.png', 'screen_name': 'BarackObama', 'text': '"Let us pause and give thanks for the fact that Nelson Mandela lived." \\u2014President Obama', 'tweet_id': 408733159090421762, 'create_time': 'Thu Dec 05 23:02:33 +0000 2013', 'location': 'Washington, DC'}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000607588261/dad9f009a228a78a14f1f4bed0c54f76_normal.png', 'screen_name': 'BarackObama', 'text': 'President Obama remembers Nelson Mandela: "A man who took history in his hands and bent the arc of the moral universe towards justice."', 'tweet_id': 408730399276154880, 'create_time': 'Thu Dec 05 22:51:35 +0000 2013', 'location': 'Washington, DC'}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000607588261/dad9f009a228a78a14f1f4bed0c54f76_normal.png', 'screen_name': 'BarackObama', 'text': 'In a single moment 58 years ago today, Rosa Parks helped change this country. http://t.co/C502SKfJnj', 'tweet_id': 407256240570396672, 'create_time': 'Sun Dec 01 21:13:49 +0000 2013', 'location': 'Washington, DC'}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000607588261/dad9f009a228a78a14f1f4bed0c54f76_normal.png', 'screen_name': 'BarackObama', 'text': "Retweet if you believe health care isn't a privilege for a fortunate few, but a right for all. #Obamacare http://t.co/NYzWBIFIOl", 'tweet_id': 402859837559545857, 'create_time': 'Tue Nov 19 18:04:04 +0000 2013', 'location': 'Washington, DC'}]}, {'BarackObama': [{'profile_pic': 'http://pbs.twimg.com/profile_images/378800000607588261/dad9f009a228a78a14f1f4bed0c54f76_normal.png', 'screen_name': 'BarackObama', 'text': '"Let us pause and give thanks for the fact that Nelson Mandela lived." \\u2014President Obama', 'tweet_id': 408733159090421762, 'create_time': 'Thu Dec 05 23:02:33 +0000 2013', 'location': 'Washington, DC'}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000607588261/dad9f009a228a78a14f1f4bed0c54f76_normal.png', 'screen_name': 'BarackObama', 'text': 'President Obama remembers Nelson Mandela: "A man who took history in his hands and bent the arc of the moral universe towards justice."', 'tweet_id': 408730399276154880, 'create_time': 'Thu Dec 05 22:51:35 +0000 2013', 'location': 'Washington, DC'}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000607588261/dad9f009a228 ...
# [{'408733159090421762': [{'profile_pic': 'http://pbs.twimg.com/profile_images/378800000799463720/cdfd051ee108b150958f7c5bd81890c1_normal.jpeg', 'name': 'Lena', 'text': "Lena, professional 1D lover, Niall's potato, 16, weird.", 'tweet_id': 411972783753949184, 'create_time': 'Sat Dec 14 21:35:40 +0000 2013', 'location': 'Germany', 'retweeter_id': 1513452349, 'screen_name': 'voguepls'}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000627445735/ce301fae3f1027e9c0316c9bf0bf7cce_normal.jpeg', 'name': '\\u2606\\u2605Erin\\u0b9cJoy\\u2665\\u266c', 'text': 'Follow your dreams\\u2323\\u030a\\u2508\\u0325-\\u0336\\u032f\\u0361\\u2648\\u0337\\u0334\\u2606 Saw @Rihanna Live #DiamondsWorldTour concert 16.10.13', 'tweet_id': 411965401367859201, 'create_time': 'Sat Dec 14 21:06:20 +0000 2013', 'location': 'Cape Town, South Africa', 'retweeter_id': 298863699, 'screen_name': 'ErinJoyd'}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000811569512/8981dbf21bf5617daa58a7cb62e4f615_normal.jpeg', 'name': 'SangeetaKaurBhopal', 'text': "psychology student at strathclyde uni. 18. Don't hate, meditate.", 'tweet_id': 411915688073519104, 'create_time': 'Sat Dec 14 17:48:47 +0000 2013', 'location': 'Glasgow, Scotland.', 'retweeter_id': 58586363, 'screen_name': 'swageeta_'}, {'profile_pic': 'http://pbs.twimg.com/profile_images/411945551085584384/Z4HSWagc_normal.jpeg', 'name': 'ils ont deux awards', 'text': "sorry i'm not good at peopleing", 'tweet_id': 411895135103123457, 'create_time': 'Sat Dec 14 16:27:07 +0000 2013', 'location': '@awesomebiebz @arianadrewlloyd', 'retweeter_id': 621831094, 'screen_name': 'janostarbuck'}, {'profile_pic': 'http://pbs.twimg.com/profile_images/411856720420278272/SLhqLJxV_normal.jpeg', 'name': 'Gina_xoxo', 'text': 'http://t.co/ZGaWF3uL3d', 'tweet_id': 411893512171700224, 'create_time': 'Sat Dec 14 16:20:40 +0000 2013', 'location': 'Mannheim; germany ', 'retweeter_id': 1267340834, 'screen_name': 'Gina_Laura_Mai'}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000805073264/ffa82efe7634b9e941b1d9db2c06b194_normal.jpeg', 'name': 'IG: Koya Oluwatobi', 'text': '@LFC @MiamiHEAT @RedSox @inter #SuperEagles.', 'tweet_id': 411893032556822528, 'create_time': 'Sat Dec 14 16:18:46 +0000 2013', 'location': 'PLUTO', 'retweeter_id': 180838616, 'screen_name': 'Tobigo12'}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000559693706/29b602ca4f41398ef5ecd4ff82f2b7e6_normal.jpeg', 'name': 'Bethany V.J Lewis ', 'text': 'R.I.P Cory Montieth/Performing Arts Student/Glee Lover/Football Fan (WBA)/Ground Hopper/Love Music/Great Personality/Follow me! I follow back! :D', 'tweet_id': 411870036291497985, 'create_time': 'Sat Dec 14 14:47:23 +0000 2013', 'location': 'Staffordshire', 'retweeter_id': 1514593261, 'screen_name': 'MsBappyLewis'}, {'profile_pic': 'http://pbs.twimg.com/profile_images/2844070785/9d7640f83de026889f35f1d7ef99dfc4_normal.jpeg', 'name': 'M\\u0128`\\u00c7\\u0124\\u00c8L\\u00c8\\ue32fR\\u00c8\\u00d1\\u00c8`', 'text': '\\u00cc\\ue32eAM M\\u0128`\\u00c7\\u0124\\u00c8L\\u00c8\\ue32fR\\u00c8\\u00d1\\u00c8` K\\u0128\\u00d1G\\ue32e.\\u2654.\\ue32eQU\\u00c8\\u00c8\\u00d1 \\u0128\\ue32eAM \\u00cc\\u2766\\u044f\\u00e9\\u0164WEE\\u0164 \\u2202\\u03c3\\u0454s\\u2766N\\u00d2Tm\\u0454\\u00e5\\u03b7 \\u00ccdis\\u00e5gree\\u2766\\u00cc\\u00e5gRee \\u00cc\\ue32eAM\\ue32e \\u2133\\u0454r\\u0454ly\\u2766\\u211b\\u0454\\u0164wee\\u0164i\\u03b7g \\ue32e\\ue131ALL\\ue131\\ue32e', 'tweet_id': 411791122160054272, 'create_time': 'Sat Dec 14 09:33:48 +0000 2013', 'location': '\\ue32e\\u00d1 \\u00d2 \\u0174\\ue32e', 'retweeter_id': 102713718, 'screen_name': 'GOLD_555_MR'}, {'profile_pic': 'http://pbs.twimg.com/profile_images/378800000400309540/1cc5ad1430072dbb4e734910903058b0_normal.jpeg', 'name': 'daniel', 'text': 'swiftie katycat brat navy gleek lovatic britneyarmy blackstar || Followed by her majesty @cherlloyd on 10-07-13 || instagram/line : danielsetyanata', 'tweet_id': 411707071336181761, 'create_time': 'Sa ...

# %%
len(person_info)
# Out:
# 4

# %%
len(total_info)
# Out:
# 4
